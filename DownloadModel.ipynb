# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %mkdir -p HeyGem

# %%
# %cd HeyGem
# Out:
# /content/drive/MyDrive/HeyGem

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/HeyGem'

# %%
# !pip install -U gdown
# !gdown --folder https://drive.google.com/drive/folders/16el0arUEDTnPHT7LIU0kU-LIMHWLGvVQ?usp=sharing
