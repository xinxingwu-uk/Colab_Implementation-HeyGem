# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HeyGem
# Out:
# /content/drive/MyDrive/HeyGem

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/HeyGem'

# %%
# %ls
# Out:
# HeyGem-Linux-Python-Hack/           TextToVideo.ipynb
# Text2Video_CompletedButMessy.ipynb

# %%
# %cd HeyGem-Linux-Python-Hack
# Out:
# /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack

# %%
# %ls
# Out:
# 1004_format.mp4
# 1004_format.wav
# 1004-r.mp4
# 1004-t.mp4
# 1.jpeg
# app.py
# check_env/
# config/
# download.sh
# example/
# face_attr_detect/
# face_detect_utils/
# face_lib/
# get-pip.py
# h_utils/
# inference_from_text.sh
# landmark2face_wy/
# license.txt
# log/
# model_lib/
# preprocess_audio_and_3dmm.cpython-38-x86_64-linux-gnu.so
# pretrain_models/
# README_en.md
# README.md
# README_tts_f2f.MD
# requirements_0.txt
# requirements.txt
# run.py
# service/
# sources.list
# tts-fish-speech/
# wenet/
# xseg/
# y_utils/

# %%
# %cd tts-fish-speech
# Out:
# /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack/tts-fish-speech

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack/tts-fish-speech'

# %%
# %cd /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack
# Out:
# /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack'

# %%
# %ls
# Out:
# 1004_format.mp4
# 1004_format.wav
# 1004-r.mp4
# 1004-t.mp4
# 1.jpeg
# app.py
# check_env/
# config/
# download.sh
# example/
# face_attr_detect/
# face_detect_utils/
# face_lib/
# get-pip.py
# h_utils/
# inference_from_text.sh
# landmark2face_wy/
# license.txt
# log/
# model_lib/
# preprocess_audio_and_3dmm.cpython-38-x86_64-linux-gnu.so
# pretrain_models/
# README_en.md
# README.md
# README_tts_f2f.MD
# requirements_0.txt
# requirements.txt
# run.py
# service/
# sources.list
# tts-fish-speech/
# wenet/
# xseg/
# y_utils/

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack'

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.1 MB/s eta 0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.6 MB/s eta 0:00:00
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-25.1.1 setuptools-80.9.0

# %%
# %cd /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack
# Out:
# /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack

# %%
# !pip install hydra-core
# !pip install pyrootutils loguru
# !pip install lightning_utilities
# Out:
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core) (24.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0.2)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Installing collected packages: hydra-core
# Successfully installed hydra-core-1.3.2
# Collecting pyrootutils
#   Downloading pyrootutils-1.0.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting python-dotenv>=0.20.0 (from pyrootutils)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading pyrootutils-1.0.4-py3-none-any.whl (5.8 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, loguru, pyrootutils
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pyrootutils]
# Successfully installed loguru-0.7.3 pyrootutils-1.0.4 python-dotenv-1.1.1
# Collecting lightning_utilities
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.11/dist-packages (from lightning_utilities) (24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning_utilities) (80.9.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning_utilities) (4.14.1)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Installing collected packages: lightning_utilities
# Successfully installed lightning_utilities-0.14.3

# %%
# !touch .project-root

# %%
# !pip install vector-quantize-pytorch
# !pip install loralib opencv-contrib-python
# Out:
# Collecting vector-quantize-pytorch
#   Downloading vector_quantize_pytorch-1.22.17-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from vector-quantize-pytorch) (0.8.1)
# Collecting einx>=0.3.0 (from vector-quantize-pytorch)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.11/dist-packages (from vector-quantize-pytorch) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from einx>=0.3.0->vector-quantize-pytorch) (2.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from einx>=0.3.0->vector-quantize-pytorch) (1.13.1)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.11/dist-packages (from einx>=0.3.0->vector-quantize-pytorch) (2.4.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0->vector-quantize-pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->vector-quantize-pytorch) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->einx>=0.3.0->vector-quantize-pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0->vector-quantize-pytorch) (3.0.2)
# Downloading vector_quantize_pytorch-1.22.17-py3-none-any.whl (47 kB)
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 82.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 177.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 159.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 29.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 120.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 144.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 135.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 61.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 189.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, einx, nvidia-cusolver-cu12, vector-quantize-pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [vector-quantize-pytorch]
# Successfully installed einx-0.3.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 vector-quantize-pytorch-1.22.17
# Collecting loralib
#   Downloading loralib-0.1.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (2.0.2)
# Downloading loralib-0.1.2-py3-none-any.whl (10 kB)
# Installing collected packages: loralib
# Successfully installed loralib-0.1.2

# %%
# !sudo apt-get update -qq && sudo apt-get install -y python3.8 python3.8-distutils


# !sudo update-alternatives --install /usr/bin/python python /usr/bin/python3.8 2
# !sudo update-alternatives --set python /usr/bin/python3.8

# !sudo python3.8 get-pip.py

# !python3.8 -m pip install --upgrade pip wheel
# !python3.8 -m pip install \
    hydra-core torch vector-quantize-pytorch \
    opencv-contrib-python-headless flask librosa cv2box onnxruntime \
    scikit-image torchvision torchaudio
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.8-minimal libpython3.8-stdlib python3.8-lib2to3 python3.8-minimal
# Suggested packages:
#   python3.8-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.8-minimal libpython3.8-stdlib python3.8 python3.8-distutils
#   python3.8-lib2to3 python3.8-minimal
# 0 upgraded, 6 newly installed, 0 to remove and 42 not upgraded.
# Need to get 5,395 kB of archives.
# After this operation, 20.1 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-minimal amd64 3.8.20-1+jammy1 [796 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-minimal amd64 3.8.20-1+jammy1 [2,023 kB]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.8-stdlib amd64 3.8.20-1+jammy1 [1,817 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8 amd64 3.8.20-1+jammy1 [440 kB]
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-lib2to3 all 3.8.20-1+jammy1 [126 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.8-distutils all 3.8.20-1+jammy1 [193 kB]
# Fetched 5,395 kB in 2s (3,508 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 6.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libpython3.8-minimal:amd64.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../0-libpython3.8-minimal_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-minimal:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-minimal.
# Preparing to unpack .../1-python3.8-minimal_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8-minimal (3.8.20-1+jammy1) ...
# Selecting previously unselected package libpython3.8-stdlib:amd64.
# Preparing to unpack .../2-libpython3.8-stdlib_3.8.20-1+jammy1_amd64.deb ...
# Unpacking libpython3.8-stdlib:amd64 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8.
# Preparing to unpack .../3-python3.8_3.8.20-1+jammy1_amd64.deb ...
# Unpacking python3.8 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-lib2to3.
# Preparing to unpack .../4-python3.8-lib2to3_3.8.20-1+jammy1_all.deb ...
# Unpacking python3.8-lib2to3 (3.8.20-1+jammy1) ...
# Selecting previously unselected package python3.8-distutils.
# Preparing to unpack .../5-python3.8-distutils_3.8.20-1+jammy1_all.deb ...
# Unpacking python3.8-distutils (3.8.20-1+jammy1) ...
# Setting up libpython3.8-minimal:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8-lib2to3 (3.8.20-1+jammy1) ...
# Setting up python3.8-minimal (3.8.20-1+jammy1) ...
# Setting up python3.8-distutils (3.8.20-1+jammy1) ...
# Setting up libpython3.8-stdlib:amd64 (3.8.20-1+jammy1) ...
# Setting up python3.8 (3.8.20-1+jammy1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python (python) in auto mode
# Collecting pip<25.1
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting setuptools
#   Downloading setuptools-75.3.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 37.9 MB/s eta 0:00:00
# Downloading setuptools-75.3.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.3 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
# Successfully installed pip-25.0.1 setuptools-75.3.2 wheel-0.45.1
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (25.0.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (0.45.1)
# Collecting hydra-core
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting torch
#   Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting vector-quantize-pytorch
#   Downloading vector_quantize_pytorch-1.14.8-py3-none-any.whl.metadata (818 bytes)
# Collecting opencv-contrib-python-headless
#   Downloading opencv_contrib_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting flask
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting cv2box
#   Downloading cv2box-0.5.9.tar.gz (52 kB)
#   Preparing metadata (setup.py) ... done
# Collecting onnxruntime
#   Downloading onnxruntime-1.19.2-cp38-cp38-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting torchvision
#   Downloading torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Collecting packaging (from hydra-core)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting importlib-resources (from hydra-core)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch)
#   Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting einops>=0.8.0 (from vector-quantize-pytorch)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting einx>=0.2 (from einx[torch]>=0.2->vector-quantize-pytorch)
#   Using cached einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting numpy<2.0 (from opencv-contrib-python-headless)
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting Werkzeug>=3.0.0 (from flask)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting itsdangerous>=2.1.2 (from flask)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting blinker>=1.6.2 (from flask)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/lib/python3/dist-packages (from flask) (4.6.4)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.58.1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting scipy>=1.6.0 (from librosa)
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Collecting scikit-learn>=1.1.0 (from librosa)
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting joblib>=1.0 (from librosa)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting decorator>=4.3.0 (from librosa)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.3.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting lazy_loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting tqdm (from cv2box)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting opencv-python (from cv2box)
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting pillow>=9.0.1 (from scikit-image)
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting imageio>=2.27 (from scikit-image)
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image)
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting frozendict (from einx>=0.2->einx[torch]>=0.2->vector-quantize-pytorch)
#   Downloading frozendict-2.4.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->torch) (2.0.1)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.41.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting PyYAML>=5.1.0 (from omegaconf<2.4,>=2.2->hydra-core)
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting platformdirs>=2.5.0 (from pooch>=1.1->librosa)
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting requests>=2.19.0 (from pooch>=1.1->librosa)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=1.1.0->librosa)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->librosa)
#   Downloading cffi-1.17.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting zipp>=3.1.0 (from importlib-resources->hydra-core)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->librosa)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting charset_normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Downloading charset_normalizer-3.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Downloading certifi-2025.7.9-py3-none-any.whl.metadata (2.4 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 30.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 40.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 111.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 114.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.8 MB/s eta 0:00:00
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 26.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 99.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 95.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 93.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 57.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 69.4 MB/s eta 0:00:00
# Downloading vector_quantize_pytorch-1.14.8-py3-none-any.whl (28 kB)
# Downloading opencv_contrib_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 43.8 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading onnxruntime-1.19.2-cp38-cp38-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 77.7 MB/s eta 0:00:00
# Downloading scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 80.3 MB/s eta 0:00:00
# Downloading torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 75.8 MB/s eta 0:00:00
# Downloading torchaudio-2.4.1-cp38-cp38-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.8 MB/s eta 0:00:00
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached einx-0.3.0-py3-none-any.whl (102 kB)
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.2 MB/s eta 0:00:00
# Downloading numba-0.58.1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 64.6 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 82.5 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 73.4 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 76.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 80.3 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 79.3 MB/s eta 0:00:00
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.3 MB/s eta 0:00:00
# Downloading soxr-0.3.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.5 MB/s eta 0:00:00
# Downloading tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 76.5 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 77.9 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading cffi-1.17.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading llvmlite-0.41.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 MB 80.7 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 26.2 MB/s eta 0:00:00
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 32.9 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Downloading frozendict-2.4.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
# Downloading nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 83.6 MB/s eta 0:00:00
# Downloading certifi-2025.7.9-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Building wheels for collected packages: antlr4-python3-runtime, cv2box
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144552 sha256=e0c011720779d69445a41c2b910a0e4a3a087c7f6545e980c775f4f3410d4e3d
#   Stored in directory: /root/.cache/pip/wheels/b1/a3/c2/6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for cv2box (setup.py) ... done
#   Created wheel for cv2box: filename=cv2box-0.5.9-py3-none-any.whl size=61402 sha256=6107a49d9d65b3b89e35486d15179726fca564550001ea22841b6c12b3d078f0
#   Stored in directory: /root/.cache/pip/wheels/c0/0e/9f/bf57b77cee211d2b562aa32434a0574d328d1f601d9c2b5414
# Successfully built antlr4-python3-runtime cv2box
# Installing collected packages: mpmath, flatbuffers, antlr4-python3-runtime, zipp, urllib3, typing-extensions, tqdm, threadpoolctl, sympy, PyYAML, pycparser, protobuf, platformdirs, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, msgpack, MarkupSafe, llvmlite, joblib, itsdangerous, idna, humanfriendly, fsspec, frozendict, filelock, einops, decorator, click, charset_normalizer, certifi, blinker, audioread, Werkzeug, triton, tifffile, soxr, scipy, requests, PyWavelets, opencv-python, opencv-contrib-python-headless, omegaconf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numba, lazy_loader, jinja2, importlib-resources, imageio, einx, coloredlogs, cffi, soundfile, scikit-learn, scikit-image, pooch, onnxruntime, nvidia-cusolver-cu12, hydra-core, flask, cv2box, torch, librosa, torchvision, torchaudio, vector-quantize-pytorch
#   Attempting uninstall: zipp
#     Found existing installation: zipp 1.0.0
#     Uninstalling zipp-1.0.0:
#       Successfully uninstalled zipp-1.0.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.4
# error: uninstall-distutils-installed-package
#
# × Cannot uninstall blinker 1.4
# ╰─> It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# !python3.8 -m pip install flask librosa cv2box scikit-image torchvision torchaudio
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.8/dist-packages (3.0.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.8/dist-packages (0.11.0)
# Requirement already satisfied: cv2box in /usr/local/lib/python3.8/dist-packages (0.5.9)
# Collecting scikit-image
#   Using cached scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting torchvision
#   Using cached torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from flask) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.8/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.8/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.8/dist-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.8/dist-packages (from flask) (1.8.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/lib/python3/dist-packages (from flask) (4.6.4)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.8/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.24.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.3.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from librosa) (4.13.2)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.8/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from cv2box) (4.67.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from cv2box) (4.12.0.88)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.8/dist-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image) (10.4.0)
# Collecting imageio>=2.27 (from scikit-image)
#   Using cached imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Using cached tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image)
#   Using cached PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.8/dist-packages (from scikit-image) (25.0)
# Collecting torch==2.4.1 (from torchvision)
#   Using cached torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (1.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (12.1.105)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.1->torchvision)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (10.3.2.106)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.1->torchvision)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.1->torchvision)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.8/dist-packages (from torch==2.4.1->torchvision) (12.1.105)
# Collecting triton==3.0.0 (from torch==2.4.1->torchvision)
#   Using cached triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.8/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1->torchvision) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.1.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.7.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from sympy->torch==2.4.1->torchvision) (1.3.0)
# Using cached scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
# Using cached torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl (7.0 MB)
# Using cached torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
# Using cached torchaudio-2.4.1-cp38-cp38-manylinux1_x86_64.whl (3.4 MB)
# Using cached imageio-2.35.1-py3-none-any.whl (315 kB)
# Using cached PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Using cached tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Installing collected packages: triton, tifffile, PyWavelets, nvidia-cusparse-cu12, nvidia-cudnn-cu12, imageio, scikit-image, nvidia-cusolver-cu12, torch, torchvision, torchaudio
# Successfully installed PyWavelets-1.4.1 imageio-2.35.1 nvidia-cudnn-cu12-9.1.0.70 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 scikit-image-0.21.0 tifffile-2023.7.10 torch-2.4.1 torchaudio-2.4.1 torchvision-0.19.1 triton-3.0.0

# %%
# !python3.8 -m pip install --upgrade pip

# !python3.8 -m pip install --upgrade --force-reinstall --ignore-installed blinker itsdangerous click Werkzeug MarkupSafe
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (25.0.1)
# Collecting blinker
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting Werkzeug
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe
#   Using cached MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Installing collected packages: MarkupSafe, itsdangerous, click, blinker, Werkzeug
# Successfully installed MarkupSafe-2.1.5 Werkzeug-3.0.6 blinker-1.8.2 click-8.1.8 itsdangerous-2.2.0

# %%
# !python3.8 -m pip install "typeguard<3.0"
# !python3.8 -m pip install matplotlib
# !python3.8 -m pip install apstone
# Out:
# Collecting typeguard<3.0
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard
# Successfully installed typeguard-2.13.3
# Collecting matplotlib
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy<2,>=1.20 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 112.3 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 136.1 MB/s eta 0:00:00
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.2 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Installing collected packages: python-dateutil, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.7.5 python-dateutil-2.9.0.post0
# Collecting apstone
#   Downloading apstone-0.0.8.tar.gz (41 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cv2box (from apstone)
#   Using cached cv2box-0.5.9-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from cv2box->apstone) (1.24.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from cv2box->apstone) (4.67.1)
# Collecting opencv-python (from cv2box->apstone)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# Building wheels for collected packages: apstone
#   Building wheel for apstone (setup.py) ... done
#   Created wheel for apstone: filename=apstone-0.0.8-py3-none-any.whl size=26401 sha256=b72f8d702c3e04a55cf413eef82fbd1657e27f3e18832e508f3250dc0485af3f
#   Stored in directory: /root/.cache/pip/wheels/7b/49/ad/47e92a4d02d2b05f063306592b66c1b592cdc227d3bea2aa9e
# Successfully built apstone
# Installing collected packages: opencv-python, cv2box, apstone
# Successfully installed apstone-0.0.8 cv2box-0.5.9 opencv-python-4.12.0.88

# %%
# !python3.8 -m pip uninstall -y onnxruntime onnxruntime-gpu || true
# !python3.8 -m pip uninstall -y onnxruntime onnxruntime-gpu || true

# !python3.8 -m pip install --upgrade "onnxruntime-gpu==1.19.2"
# python3.8 -m pip install --extra-index-url https://download.onnxruntime.ai/ \
#            "onnxruntime-gpu==1.18.0+cu122"
# Out:
# WARNING: Skipping onnxruntime as it is not installed.
# WARNING: Skipping onnxruntime-gpu as it is not installed.
# WARNING: Skipping onnxruntime as it is not installed.
# WARNING: Skipping onnxruntime-gpu as it is not installed.
# Collecting onnxruntime-gpu==1.19.2
#   Downloading onnxruntime_gpu-1.19.2-cp38-cp38-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime-gpu==1.19.2)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.8/dist-packages (from onnxruntime-gpu==1.19.2) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.8/dist-packages (from onnxruntime-gpu==1.19.2) (1.24.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from onnxruntime-gpu==1.19.2) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from onnxruntime-gpu==1.19.2) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime-gpu==1.19.2) (1.13.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.8/dist-packages (from coloredlogs->onnxruntime-gpu==1.19.2) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime-gpu==1.19.2) (1.3.0)
# Downloading onnxruntime_gpu-1.19.2-cp38-cp38-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (226.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.2/226.2 MB 44.3 MB/s eta 0:00:00
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Installing collected packages: coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 onnxruntime-gpu-1.19.2

# %%
# !python3.8 -m pip install --upgrade numexpr
# Out:
# Collecting numexpr
#   Downloading numexpr-2.8.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from numexpr) (1.24.4)
# Downloading numexpr-2.8.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
# Installing collected packages: numexpr
# Successfully installed numexpr-2.8.6

# %%
# %ls
# Out:
# 1004_format.mp4
# 1004_format.wav
# 1004-r.mp4
# 1004-t.mp4
# 1.jpeg
# app.py
# check_env/
# config/
# download.sh
# example/
# face_attr_detect/
# face_detect_utils/
# face_lib/
# get-pip.py
# h_utils/
# inference_from_text.sh*
# landmark2face_wy/
# license.txt
# log/
# model_lib/
# preprocess_audio_and_3dmm.cpython-38-x86_64-linux-gnu.so
# pretrain_models/
# README_en.md
# README.md
# README_tts_f2f.MD
# requirements_0.txt
# requirements.txt
# run.py
# service/
# sources.list
# tts-fish-speech/
# wenet/
# xseg/
# y_utils/

# %%
# !python3.8 -m pip install flask librosa torch scikit-image torchvision torchaudio

# %%
# !python3.8 run.py --audio_path example/song.mp3 --video_path example/videoSing.mp4
# Out:
# 2025-07-12 21:42:25,312 - cv2box - INFO - Use default multi mode: multi-thread, or you can set env 'CV_MULTI_MODE' to multi-process/torch-process
# [2025-07-12 21:42:27] [run.py[line:184]] [INFO] [TransDhTask init]
# run.py:184: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   task = service.trans_dh_service.TransDhTask()
# 检测人脸使用GPU
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#             audio_feature: 3dmm
#                batch_size: 16
#           checkpoints_dir: ./landmark2face_wy/checkpoints
#                 crop_size: 256
#                  dataroot: ./data
#              dataset_mode: Facereala3dmm
#                 direction: AtoB
#           display_winsize: 256
#               distributed: False
#                     epoch: latest
#                      eval: False
#                  feat_num: 3
#              feature_path: ../AnnI_deep3dface_256_contains_id/
#                      fp16: False
#                   gpu_ids: 0
#                  img_size: 256
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#             instance_feat: False
#                   isTrain: False                         	[default: None]
#                label_feat: False
#                  lan_size: 1
#             load_features: False
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                local_rank: -1
#          max_dataset_size: inf
#                mfcc0_rate: 0.2
#                     model: pirender_3dmm_mouth_hd
#                model_path: ./landmark2face_wy/checkpoints/anylang/dinet_v1_20240131.pth
#                  n_blocks: 9
#           n_blocks_global: 9
#            n_blocks_local: 3
#                n_clusters: 10
#            n_downsample_E: 4
#       n_downsample_global: 4
#                n_layers_D: 3
#         n_local_enhancers: 1
#                      name: test
#                       ndf: 64
#                       nef: 16
#                      netD: basic
#                      netG: pirender
#                       ngf: 64
#          niter_fix_global: 0
#                no_dropout: True
#                   no_flip: False
#           no_ganFeat_loss: False
#               no_instance: False
#                      norm: instance
#                     ntest: inf
#                     num_D: 2
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 3
#         perceptual_layers: ['relu_1_1', 'relu_2_1', 'relu_3_1', 'relu_4_1', 'relu_5_1']
#        perceptual_network: vgg19
#     perceptual_num_scales: 4
# perceptual_use_style_loss: True
#        perceptual_weights: [4, 4, 4, 4, 4]
#                     phase: test
#                preprocess: resize_and_crop
#               resize_size: 512
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#           test_audio_path: None
#                test_muban: None
#                   verbose: False
# weight_style_to_perceptual: 250
# ----------------- End -------------------
# /usr/lib/python3.8/multiprocessing/process.py:108: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self._target(*self._args, **self._kwargs)
# warning: det_size is already set in scrfd model, ignore
# [2025-07-12 21:42:32] [process.py[line:108]] [INFO] [>>> init_wh_process进程启动]
# [2025-07-12 21:42:38] [run.py[line:188]] [INFO] [任务:1004 -> audio_url:./example/song.mp3  video_url:./example/videoSing.mp4]
# --------------------> download cost: 4.291534423828125e-06
# [2025-07-12 21:42:38] [run.py[line:188]] [INFO] [[1004] -> ffmpeg video: ffmpeg -loglevel warning -i ./example/videoSing.mp4 -crf 15 -vcodec copy -an -y ./1004_format.mp4]
# [2025-07-12 21:42:39] [run.py[line:188]] [INFO] [[1004] -> ffmpeg audio: ffmpeg -loglevel warning -i ./example/song.mp3 -ac 1 -ar 16000 -acodec pcm_s16le -y  ./1004_format.wav]
# [2025-07-12 21:42:39] [run.py[line:188]] [INFO] [[1004] -> 预处理耗时:1.4143764972686768s]
# >>> 777   6
# use_time: 0.982020378112793 torch.Size([1, 874, 256])
# use_time: 0.030335664749145508 torch.Size([1, 874, 256])
# use_time: 0.0286409854888916 torch.Size([1, 874, 256])
# use_time: 0.052622318267822266 torch.Size([1, 874, 256])
# use_time: 0.04909014701843262 torch.Size([1, 874, 256])
# Model warm up done !
# use_time: 0.03134918212890625 torch.Size([1, 874, 256])
# 检测人脸使用GPU
# warning: det_size is already set in scrfd model, ignore
# use_time: 0.04337596893310547 torch.Size([1, 769, 256])
# [2025-07-12 21:42:43] [run.py[line:188]] [INFO] [[1004] -> get_aud_feat1 cost:3.480926752090454s]
# [2025-07-12 21:42:43] [process.py[line:108]] [INFO] [>>> 数字人图片处理进程启动]
# [2025-07-12 21:42:46] [process.py[line:108]] [INFO] [[1004]init_wh result :[0.9511786830837108]， cost: 7.086407899856567 s]
# [2025-07-12 21:42:46] [run.py[line:188]] [INFO] [[1004] -> wh: [0.9511786830837108]]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [[1004]任务视频驱动队列启动 batch_size:4, len:1440]
# in template video function
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 开始循环]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:4]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:8]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [>>> audio_transfer get message:4]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:12]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:16]
# [2025-07-12 21:42:50] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:20]
# [2025-07-12 21:42:51] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:24]
# [2025-07-12 21:42:51] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:28]
# [2025-07-12 21:42:51] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:32]
# [2025-07-12 21:42:51] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:36]
# [2025-07-12 21:42:51] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:40]
# [2025-07-12 21:42:51] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:44]
# [2025-07-12 21:42:53] [process.py[line:108]] [INFO] [[1004] -> frame_id:[4] 模糊置信度:[0.978]]
# [2025-07-12 21:42:53] [process.py[line:108]] [INFO] [[1004] -> need chaofen .]
# [2025-07-12 21:42:53] [utils.py[line:148]] [INFO] [Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.]
# [2025-07-12 21:42:53] [utils.py[line:160]] [INFO] [NumExpr defaulting to 8 threads.]
# [2025-07-12 21:42:53] [process.py[line:108]] [INFO] [[4] -> chaofen  cost:2.5903735160827637s]
# Custom VideoWriter init done
# 4/4/usr/lib/python3.8/multiprocessing/process.py:108: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   self._target(*self._args, **self._kwargs)
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:4373: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# 8/4[2025-07-12 21:43:06] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:4, cost:15.822088479995728s]
# [2025-07-12 21:43:06] [process.py[line:108]] [INFO] [>>> audio_transfer get message:8]
# [2025-07-12 21:43:06] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:48]
# [2025-07-12 21:43:06] [process.py[line:108]] [INFO] [[8] -> chaofen  cost:0.1618821620941162s]
# 8/4[2025-07-12 21:43:07] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:8, cost:0.3400599956512451s]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [>>> audio_transfer get message:12]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:52]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [[12] -> chaofen  cost:0.15075421333312988s]
# 8/4[2025-07-12 21:43:07] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:12, cost:0.3299403190612793s]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [>>> audio_transfer get message:16]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:56]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [[16] -> chaofen  cost:0.1475963592529297s]
# 8/4[2025-07-12 21:43:07] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:16, cost:0.297680139541626s]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [>>> audio_transfer get message:20]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:60]
# [2025-07-12 21:43:07] [process.py[line:108]] [INFO] [[20] -> chaofen  cost:0.14584922790527344s]
# 8/4[2025-07-12 21:43:08] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:20, cost:0.29366636276245117s]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [>>> audio_transfer get message:24]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:64]
# in template video function
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 开始循环]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [[24] -> chaofen  cost:0.157639741897583s]
# 8/4[2025-07-12 21:43:08] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:24, cost:0.30970191955566406s]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [>>> audio_transfer get message:28]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[3], current_idx:67]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [[28] -> chaofen  cost:0.15104055404663086s]
# 8/4[2025-07-12 21:43:08] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:28, cost:0.30042314529418945s]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [>>> audio_transfer get message:32]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:71]
# [2025-07-12 21:43:08] [process.py[line:108]] [INFO] [[32] -> chaofen  cost:0.14689850807189941s]
# 8/4[2025-07-12 21:43:09] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:32, cost:0.2954409122467041s]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [>>> audio_transfer get message:36]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:75]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [[36] -> chaofen  cost:0.15262269973754883s]
# 8/4[2025-07-12 21:43:09] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:36, cost:0.3025240898132324s]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [>>> audio_transfer get message:40]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:79]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [[40] -> chaofen  cost:0.14612817764282227s]
# 8/4[2025-07-12 21:43:09] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:40, cost:0.2978038787841797s]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [>>> audio_transfer get message:44]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:83]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [[44] -> chaofen  cost:0.14855027198791504s]
# 8/4[2025-07-12 21:43:09] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:44, cost:0.2986311912536621s]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [>>> audio_transfer get message:48]
# [2025-07-12 21:43:09] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:87]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [[48] -> chaofen  cost:0.15563416481018066s]
# 8/4[2025-07-12 21:43:10] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:48, cost:0.31493544578552246s]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [>>> audio_transfer get message:52]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:91]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [[52] -> chaofen  cost:0.15553736686706543s]
# 8/4[2025-07-12 21:43:10] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:52, cost:0.3073606491088867s]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [>>> audio_transfer get message:56]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:95]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [[56] -> chaofen  cost:0.14870810508728027s]
# 8/4[2025-07-12 21:43:10] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:56, cost:0.3018364906311035s]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [>>> audio_transfer get message:60]
# [2025-07-12 21:43:10] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:99]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [[60] -> chaofen  cost:0.15462779998779297s]
# 8/4[2025-07-12 21:43:11] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:60, cost:0.3084695339202881s]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [>>> audio_transfer get message:64]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:103]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [[64] -> chaofen  cost:0.15154695510864258s]
# 8/4[2025-07-12 21:43:11] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:64, cost:0.30664706230163574s]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [>>> audio_transfer get message:67]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:107]
# [2025-07-12 21:43:11] [process.py[line:108]] [INFO] [[67] -> chaofen  cost:0.11443567276000977s]
# 4/3[2025-07-12 21:43:15] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:3, frameId:67, cost:3.668058395385742s]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [>>> audio_transfer get message:71]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:111]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [[71] -> chaofen  cost:0.1484544277191162s]
# 8/4[2025-07-12 21:43:15] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:71, cost:0.32535696029663086s]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [>>> audio_transfer get message:75]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:115]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [[75] -> chaofen  cost:0.1491549015045166s]
# 8/4[2025-07-12 21:43:15] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:75, cost:0.32962656021118164s]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [>>> audio_transfer get message:79]
# [2025-07-12 21:43:15] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:119]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [[79] -> chaofen  cost:0.14820194244384766s]
# 8/4[2025-07-12 21:43:16] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:79, cost:0.30275416374206543s]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [>>> audio_transfer get message:83]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:123]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [[83] -> chaofen  cost:0.14592504501342773s]
# 8/4[2025-07-12 21:43:16] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:83, cost:0.29736876487731934s]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [>>> audio_transfer get message:87]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:127]
# in template video function
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 开始循环]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [[87] -> chaofen  cost:0.15493988990783691s]
# 8/4[2025-07-12 21:43:16] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:87, cost:0.3055002689361572s]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [>>> audio_transfer get message:91]
# [2025-07-12 21:43:16] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[7], current_idx:134]
# [2025-07-12 21:43:17] [process.py[line:108]] [INFO]

# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [>>> audio_transfer get message:233]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:276]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [[233] -> chaofen  cost:0.1509113311767578s]
# 8/4[2025-07-12 21:43:28] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:233, cost:0.3000669479370117s]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [>>> audio_transfer get message:237]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:280]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [[237] -> chaofen  cost:0.14693641662597656s]
# 8/4[2025-07-12 21:43:28] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:237, cost:0.29828858375549316s]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [>>> audio_transfer get message:241]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:284]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [[241] -> chaofen  cost:0.15030169486999512s]
# 8/4[2025-07-12 21:43:28] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:241, cost:0.30143141746520996s]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [>>> audio_transfer get message:245]
# [2025-07-12 21:43:28] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:288]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [[245] -> chaofen  cost:0.15052437782287598s]
# 8/4[2025-07-12 21:43:29] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:245, cost:0.30098414421081543s]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [>>> audio_transfer get message:249]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:292]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [[249] -> chaofen  cost:0.14708662033081055s]
# 8/4[2025-07-12 21:43:29] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:249, cost:0.29737377166748047s]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [>>> audio_transfer get message:253]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:296]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [[253] -> chaofen  cost:0.14939379692077637s]
# 8/4[2025-07-12 21:43:29] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:253, cost:0.2998485565185547s]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [>>> audio_transfer get message:257]
# [2025-07-12 21:43:29] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:300]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [[257] -> chaofen  cost:0.1494898796081543s]
# 8/4[2025-07-12 21:43:30] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:257, cost:0.30669713020324707s]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [>>> audio_transfer get message:264]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:304]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [[264] -> chaofen  cost:0.2509801387786865s]
# 8/7[2025-07-12 21:43:30] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:7, frameId:264, cost:0.5130140781402588s]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [>>> audio_transfer get message:268]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:308]
# [2025-07-12 21:43:30] [process.py[line:108]] [INFO] [[268] -> chaofen  cost:0.15232372283935547s]
# 8/4[2025-07-12 21:43:31] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:268, cost:0.3039360046386719s]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [>>> audio_transfer get message:272]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:312]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [[272] -> chaofen  cost:0.1454176902770996s]
# 8/4[2025-07-12 21:43:31] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:272, cost:0.2952742576599121s]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [>>> audio_transfer get message:276]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:316]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [[276] -> chaofen  cost:0.14442825317382812s]
# 8/4[2025-07-12 21:43:31] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:276, cost:0.29471921920776367s]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [>>> audio_transfer get message:280]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:320]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [[280] -> chaofen  cost:0.14553022384643555s]
# 8/4[2025-07-12 21:43:31] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:280, cost:0.291867733001709s]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [>>> audio_transfer get message:284]
# [2025-07-12 21:43:31] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:324]
# in template video function
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 开始循环]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [[284] -> chaofen  cost:0.16204524040222168s]
# 8/4[2025-07-12 21:43:32] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:284, cost:0.3128941059112549s]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [>>> audio_transfer get message:288]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[3], current_idx:327]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [[288] -> chaofen  cost:0.14855241775512695s]
# 8/4[2025-07-12 21:43:32] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:288, cost:0.30205845832824707s]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [>>> audio_transfer get message:292]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:331]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [[292] -> chaofen  cost:0.14668011665344238s]
# 8/4[2025-07-12 21:43:32] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:292, cost:0.2975642681121826s]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [>>> audio_transfer get message:296]
# [2025-07-12 21:43:32] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:335]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [[296] -> chaofen  cost:0.15192174911499023s]
# 8/4[2025-07-12 21:43:33] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:296, cost:0.30438661575317383s]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [>>> audio_transfer get message:300]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:339]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [[300] -> chaofen  cost:0.14627766609191895s]
# 8/4[2025-07-12 21:43:33] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:300, cost:0.29882216453552246s]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [>>> audio_transfer get message:304]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [drivered_video >>>>>>>>>>>>>>>>>>>> 发送数据大小:[4], current_idx:343]
# [2025-07-12 21:43:33] [process.py[line:108]] [INFO] [[304] -> chaofen  cost:0.14899063110351562s]
# 8/4[2025-07-12 21:43:33] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId
[process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1395, cost:0.29949045181274414s]
# [2025-07-12 21:44:59] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1399]
# [2025-07-12 21:44:59] [process.py[line:108]] [INFO] [[1004]任务预处理进程结束]
# [2025-07-12 21:45:00] [process.py[line:108]] [INFO] [[1399] -> chaofen  cost:0.14711403846740723s]
# 8/4[2025-07-12 21:45:00] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1399, cost:0.29793810844421387s]
# [2025-07-12 21:45:00] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1403]
# [2025-07-12 21:45:00] [process.py[line:108]] [INFO] [[1403] -> chaofen  cost:0.14617061614990234s]
# 8/4[2025-07-12 21:45:00] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1403, cost:0.30753469467163086s]
# [2025-07-12 21:45:00] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1407]
# [2025-07-12 21:45:00] [process.py[line:108]] [INFO] [[1407] -> chaofen  cost:0.14501476287841797s]
# 8/4[2025-07-12 21:45:00] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1407, cost:0.2990553379058838s]
# [2025-07-12 21:45:00] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1411]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [[1411] -> chaofen  cost:0.15196943283081055s]
# 8/4[2025-07-12 21:45:01] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1411, cost:0.31469106674194336s]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1415]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [[1415] -> chaofen  cost:0.15217351913452148s]
# 8/4[2025-07-12 21:45:01] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1415, cost:0.3035898208618164s]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1419]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [[1419] -> chaofen  cost:0.15370464324951172s]
# 8/4[2025-07-12 21:45:01] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1419, cost:0.3044140338897705s]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1423]
# [2025-07-12 21:45:01] [process.py[line:108]] [INFO] [[1423] -> chaofen  cost:0.14612078666687012s]
# 8/4[2025-07-12 21:45:02] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1423, cost:0.2995479106903076s]
# [2025-07-12 21:45:02] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1427]
# [2025-07-12 21:45:02] [process.py[line:108]] [INFO] [[1427] -> chaofen  cost:0.1567082405090332s]
# 8/4[2025-07-12 21:45:02] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1427, cost:0.3148369789123535s]
# [2025-07-12 21:45:02] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1434]
# [2025-07-12 21:45:02] [process.py[line:108]] [INFO] [[1434] -> chaofen  cost:0.25289154052734375s]
# 8/7[2025-07-12 21:45:02] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:7, frameId:1434, cost:0.513200044631958s]
# [2025-07-12 21:45:03] [process.py[line:108]] [INFO] [>>> audio_transfer get message:1438]
# [2025-07-12 21:45:03] [process.py[line:108]] [INFO] [[1438] -> chaofen  cost:0.15115904808044434s]
# 8/4[2025-07-12 21:45:03] [process.py[line:108]] [INFO] [audio_transfer >>>>>>>>>>> 发送完成数据大小:4, frameId:1438, cost:0.3066294193267822s]
# [2025-07-12 21:45:03] [process.py[line:108]] [INFO] [>>> audio_transfer get exception msg:-1]
# [2025-07-12 21:45:03] [process.py[line:108]] [INFO] [[1004]任务数字人图片处理已完成]
# [2025-07-12 21:45:03] [run.py[line:71]] [INFO] [Custom VideoWriter [1004]视频帧队列处理已结束]
# [2025-07-12 21:45:03] [run.py[line:74]] [INFO] [Custom VideoWriter Silence Video saved in /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack/1004-t.mp4]
# [2025-07-12 21:45:03] [run.py[line:146]] [INFO] [Custom command:ffmpeg -loglevel warning -y -i ./example/song.mp3 -i ./1004-t.mp4 -c:a aac -c:v libx264 -crf 15 -strict -2 ./1004-r.mp4]
# ###### Custom Video Writer write over
# ###### Video result saved in /content/drive/MyDrive/HeyGem/HeyGem-Linux-Python-Hack/1004-r.mp4
# [2025-07-12 21:45:31] [run.py[line:188]] [INFO] [>>> 任务:1004 耗时:173.0061001777649 ]
